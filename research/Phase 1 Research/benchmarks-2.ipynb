# %%
# !git clone --depth 1 https://github.com/EleutherAI/lm-evaluation-harness
# Out:
# Cloning into 'lm-evaluation-harness'...
# remote: Enumerating objects: 4526, done.
# remote: Counting objects: 100% (4526/4526), done.
# remote: Compressing objects: 100% (2553/2553), done.
# remote: Total 4526 (delta 2079), reused 3704 (delta 1949), pack-reused 0 (from 0)
# Receiving objects: 100% (4526/4526), 1.60 MiB | 3.49 MiB/s, done.
# Resolving deltas: 100% (2079/2079), done.

# %%
# !pip install -e /kaggle/working/lm-evaluation-harness
# Out:
# Obtaining file:///kaggle/working/lm-evaluation-harness
# done
#   Checking if build backend supports build_editable ... done
# done
# done
# ...
# done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.8 MB/s eta 0:00:00
# ...
# done
# ...
# done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 12.9 MB/s eta 0:00:00
# ...
# done
#   Created wheel for lm_eval: filename=lm_eval-0.4.4-0.editable-py3-none-any.whl size=19217 sha256=b6fb690366a2953f6d7f4e59794e0cde272c6bf4cc007faf22b7fa3366f49b68
#   Stored in directory: /tmp/pip-ephem-wheel-cache-10bibk4z/wheels/1b/1a/1b/44c80ddb18c9d7d3ce79a8d6d4561bddaddcbffb4cdfbf3259
# done
# ...

# %%
from huggingface_hub import login
login(token='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')
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !lm_eval --model hf \
    --model_args pretrained=meta-llama/Llama-2-7b-hf\
    --tasks hellaswag \
    --device cuda:1 \
    --batch_size 8
# Out:
# ...
# tokenizer_config.json: 100%|███████████████████| 776/776 [00:00<00:00, 3.92MB/s]
# tokenizer.model: 100%|███████████████████████| 500k/500k [00:00<00:00, 12.2MB/s]
# tokenizer.json: 100%|██████████████████████| 1.84M/1.84M [00:00<00:00, 7.28MB/s]
# special_tokens_map.json: 100%|█████████████████| 414/414 [00:00<00:00, 2.51MB/s]
# model.safetensors.index.json: 100%|████████| 26.8k/26.8k [00:00<00:00, 87.3MB/s]
# ...
# model-00001-of-00002.safetensors:   0%|             | 0.00/9.98G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|     | 31.5M/9.98G [00:00<00:42, 236MB/s]
# model-00001-of-00002.safetensors:   1%|     | 62.9M/9.98G [00:00<00:36, 271MB/s]
# model-00001-of-00002.safetensors:   1%|     | 94.4M/9.98G [00:00<00:34, 283MB/s]
# model-00001-of-00002.safetensors:   1%|      | 126M/9.98G [00:00<00:34, 288MB/s]
# model-00001-of-00002.safetensors:   2%|      | 157M/9.98G [00:00<00:33, 292MB/s]
# model-00001-of-00002.safetensors:   2%|      | 189M/9.98G [00:00<00:33, 296MB/s]
# ...

# %%
# !lm_eval --model hf \
    --model_args pretrained=distilbert/distilbert-base-uncased\
    --tasks hellaswag \
    --device cuda:1 \
    --batch_size 8
# Out:
# config.json: 100%|█████████████████████████████| 483/483 [00:00<00:00, 2.99MB/s]
# tokenizer_config.json: 100%|██████████████████| 48.0/48.0 [00:00<00:00, 290kB/s]
# vocab.txt: 100%|█████████████████████████████| 232k/232k [00:00<00:00, 1.79MB/s]
# tokenizer.json: 100%|████████████████████████| 466k/466k [00:00<00:00, 3.55MB/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Traceback (most recent call last):
#   File "/opt/conda/bin/lm_eval", line 8, in <module>
#     sys.exit(cli_evaluate())
#   File "/kaggle/working/lm-evaluation-harness/lm_eval/__main__.py", line 382, in cli_evaluate
#     results = evaluator.simple_evaluate(
# ...

# %%
# !lm_eval --model hf \
    --model_args pretrained=google/gemma-7b\
    --tasks hellaswag \
    --device cuda:1 \
    --batch_size 8
# Out:
# config.json: 100%|█████████████████████████████| 629/629 [00:00<00:00, 4.16MB/s]
# tokenizer_config.json: 100%|███████████████| 33.6k/33.6k [00:00<00:00, 4.59MB/s]
# tokenizer.model: 100%|█████████████████████| 4.24M/4.24M [00:00<00:00, 63.5MB/s]
# tokenizer.json: 100%|██████████████████████| 17.5M/17.5M [00:00<00:00, 92.2MB/s]
# special_tokens_map.json: 100%|█████████████████| 636/636 [00:00<00:00, 3.94MB/s]
# model.safetensors.index.json: 100%|████████| 20.9k/20.9k [00:00<00:00, 75.4MB/s]
# ...
# model-00001-of-00004.safetensors:   0%|             | 0.00/5.00G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   1%|     | 41.9M/5.00G [00:00<00:13, 361MB/s]
# model-00001-of-00004.safetensors:   2%|     | 83.9M/5.00G [00:00<00:13, 360MB/s]
# model-00001-of-00004.safetensors:   3%|▏     | 126M/5.00G [00:00<00:13, 354MB/s]
# model-00001-of-00004.safetensors:   3%|▏     | 168M/5.00G [00:00<00:14, 343MB/s]
# model-00001-of-00004.safetensors:   4%|▎     | 210M/5.00G [00:00<00:14, 337MB/s]
# ...

# %%
# !lm_eval --model hf \
    --model_args pretrained=google/gemma-2-9b\
    --tasks hellaswag \
    --device cuda:1 \
    --batch_size 8
# Out:
# config.json: 100%|█████████████████████████████| 856/856 [00:00<00:00, 4.53MB/s]
# tokenizer_config.json: 100%|███████████████| 46.4k/46.4k [00:00<00:00, 7.96MB/s]
# tokenizer.model: 100%|█████████████████████| 4.24M/4.24M [00:00<00:00, 64.1MB/s]
# tokenizer.json: 100%|███████████████████████| 17.5M/17.5M [00:00<00:00, 256MB/s]
# special_tokens_map.json: 100%|█████████████████| 636/636 [00:00<00:00, 4.47MB/s]
# model.safetensors.index.json: 100%|████████| 39.1k/39.1k [00:00<00:00, 72.6MB/s]
# ...
# model-00001-of-00008.safetensors:   0%|             | 0.00/4.84G [00:00<?, ?B/s]
# model-00001-of-00008.safetensors:   1%|     | 31.5M/4.84G [00:00<00:15, 309MB/s]
# model-00001-of-00008.safetensors:   1%|     | 62.9M/4.84G [00:00<00:16, 295MB/s]
# model-00001-of-00008.safetensors:   2%|     | 94.4M/4.84G [00:00<00:16, 294MB/s]
# model-00001-of-00008.safetensors:   3%|▏     | 126M/4.84G [00:00<00:16, 292MB/s]
# model-00001-of-00008.safetensors:   3%|▏     | 157M/4.84G [00:00<00:16, 290MB/s]
# ...

# %%
# !lm_eval --tasks list
